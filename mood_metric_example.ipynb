# %% [markdown]
# # Import from .py File

# %%
from mood_metric_git_version import *

# %% [markdown]
# # Excerpt from NYT Opinion Column on Trump's Impeachment

# %%
text = "Given the dishonesty, if not downright absurdity, of some passages in the speech, it was perhaps a human reaction on the part of the House speaker, Nancy Pelosi, to tear it to shreds. It was still disappointing to see her stoop to the kind of stunt the president himself would pull, and, as she certainly knows as well as anyone, a gesture like that won’t defeat the president’s argument. So what will?"

# %% [markdown]
# # Plot Mood Scores Using DepecheMood

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# categories
emo_name = ['AFRAID','AMUSED','ANGRY','ANNOYED','DONT_CARE','HAPPY','INSPIRED','SAD']

# score
emo_class, score = mood_metric_scores(dm,text)

# plot the scores
plt.figure(figsize=(10,7))
df = pd.DataFrame({'emotion':emo_name, 'score':score})
ax = sns.barplot(x='emotion', y='score', data=df, palette="hls")
ax.set_xlabel('mood', fontsize = 25)
ax.set_ylabel('score', fontsize = 25)
ax.tick_params(axis="x", labelsize=15, labelrotation=45)
ax.tick_params(axis="y", labelsize=15, labelrotation=45)
# Out:
# 74it [00:00, 645.19it/s]
